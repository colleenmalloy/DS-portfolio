# %% [markdown]
# # Project 8 -- Colleen Malloy

# %% [markdown]
# **TA Help:**
#
# **Collaboration:**

# %% [markdown]
# ## Question 1

# %%
#1a
import pandas as pd
indy_climatedata_2006 = pd.read_csv("/anvil/projects/tdm/data/noaa_timeseries/indyclimatedata_2006.csv", low_memory=False)

indy_climatedata_2006.head()

#There is a backup lat and lon which is interesting. I wonder what those values are for. - Are they the back of the plane? 
#I think a lot of this is interesting and useful. The missing values I see are for things like weather, which they probably just didn't expereince that day.
# Out:
#        STATION                 DATE  LATITUDE  LONGITUDE  ELEVATION  \
# 0  USW00093819  2006-01-01T00:00:00  39.72517  -86.28168      241.1
# 1  USW00093819  2006-01-01T00:00:00  39.72517  -86.28168      241.1
# 2  USW00093819  2006-01-01T00:00:00  39.72517  -86.28168      241.1
# 3  USW00093819  2006-01-01T00:02:00  39.72517  -86.28168      241.1
# 4  USW00093819  2006-01-01T00:55:00  39.72517  -86.28168      241.1
#
#                                         NAME REPORT_TYPE  SOURCE  \
# 0  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US       FM-15   335.0
# 1  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US         SOD     NaN
# 2  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US         SOM     NaN
# 3  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US       FM-16   343.0
# 4  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US       FM-15   343.0
#
#    HourlyAltimeterSetting  HourlyDewPointTemperature  ...  BackupDirection  \
# 0                  1013.5                       -2.0  ...                S
# 1                     NaN                        NaN  ...                S
# 2                     NaN                        NaN  ...                S
# 3                  1013.2                       -2.0  ...                S
# 4                  1012.9                       -2.2  ...                S
#
#   BackupDistance BackupDistanceUnit                         BackupElements  \
# 0           1.26                 mi  PRECIP, SNOWFALL, SNOWDPTH, SNOWWTREQ
# 1           1.26                 mi  PRECIP, SNOWFALL, SNOWDPTH, SNOWWTREQ
# 2           1.26                 mi  PRECIP, SNOWFALL, SNOWDPTH, SNOWWTREQ
# 3           1.26                 mi  PRECIP, SNOWFALL, SNOWDPTH, SNOWWTREQ
# 4           1.26                 mi  PRECIP, SNOWFALL, SNOWDPTH, SNOWWTREQ
#
#    BackupElevation            BackupEquipment BackupLatitude  BackupLongitude  \
# 0              790  SRG, SNOWSTICK, SNOWBOARD        39.7069         -86.2808
# 1              790  SRG, SNOWSTICK, SNOWBOARD        39.7069         -86.2808
# 2              790  SRG, SNOWSTICK, SNOWBOARD        39.7069         -86.2808
# 3              790  SRG, SNOWSTICK, SNOWBOARD        39.7069         -86.2808
# 4              790  SRG, SNOWSTICK, SNOWBOARD        39.7069         -86.2808
#
#    BackupName WindEquipmentChangeDate
# 0     WFO IND              05/22/2007
# 1     WFO IND              05/22/2007
# 2     WFO IND              05/22/2007
# 3     WFO IND              05/22/2007
# 4     WFO IND              05/22/2007
#
# [5 rows x 125 columns]

# %%
#1b
indy_climatedata_2006.shape
# Out:
# (16764, 125)

# %%
pd.set_option('display.max_rows', None) 
indy_climatedata_2006.dtypes
# Out:
# STATION                                          object
# DATE                                             object
# LATITUDE                                        float64
# LONGITUDE                                       float64
# ELEVATION                                       float64
# NAME                                             object
# REPORT_TYPE                                      object
# SOURCE                                          float64
# HourlyAltimeterSetting                          float64
# HourlyDewPointTemperature                       float64
# HourlyDryBulbTemperature                        float64
# HourlyPrecipitation                              object
# HourlyPresentWeatherType                         object
# HourlyPressureChange                            float64
# HourlyPressureTendency                          float64
# HourlyRelativeHumidity                          float64
# HourlySkyConditions                              object
# HourlySeaLevelPressure                          float64
# HourlyStationPressure                           float64
# HourlyVisibility                                 object
# HourlyWetBulbTemperature                        float64
# HourlyWindDirection                              object
# HourlyWindGustSpeed                             float64
# HourlyWindSpeed                                 float64
# Sunrise                                         float64
# Sunset                                          float64
# DailyAverageDewPointTemperature                 float64
# DailyAverageDryBulbTemperature                  float64
# DailyAverageRelativeHumidity                    float64
# DailyAverageSeaLevelPressure                    float64
# DailyAverageStationPressure                     float64
# DailyAverageWetBulbTemperature                  float64
# DailyAverageWindSpeed                           float64
# DailyCoolingDegreeDays                          float64
# DailyDepartureFromNormalAverageTemperature      float64
# DailyHeatingDegreeDays                          float64
# DailyMaximumDryBulbTemperature                  float64
# DailyMinimumDryBulbTemperature                  float64
# DailyPeakWindDirection                          float64
# DailyPeakWindSpeed                              float64
# DailyPrecipitation                               object
# DailySnowDepth                                   object
# DailySnowfall                                    object
# DailySustainedWindDirection                     float64
# DailySustainedWindSpeed                         float64
# DailyWeather                                     object
# MonthlyAverageRH                                float64
# MonthlyDaysWithGT001Precip                      float64
# MonthlyDaysWithGT010Precip                      float64
# MonthlyDaysWithGT32Temp                         float64
# MonthlyDaysWithGT90Temp                         float64
# MonthlyDaysWithLT0Temp                          float64
# MonthlyDaysWithLT32Temp                         float64
# MonthlyDepartureFromNormalAverageTemperature    float64
# MonthlyDepartureFromNormalCoolingDegreeDays     float64
# MonthlyDepartureFromNormalHeatingDegreeDays     float64
# MonthlyDepartureFromNormalMaximumTemperature    float64
# MonthlyDepartureFromNormalMinimumTemperature    float64
# MonthlyDepartureFromNormalPrecipitation         float64
# MonthlyDewpointTemperature                      float64
# MonthlyGreatestPrecip                           float64
# MonthlyGreatestPrecipDate                        object
# MonthlyGreatestSnowDepth                         object
# MonthlyGreatestSnowDepthDate                    float64
# MonthlyGreatestSnowfall                          object
# MonthlyGreatestSnowfallDate                      object
# MonthlyMaxSeaLevelPressureValue                 float64
# MonthlyMaxSeaLevelPressureValueDate             float64
# MonthlyMaxSeaLevelPressureValueTime             float64
# MonthlyMaximumTemperature                       float64
# MonthlyMeanTemperature                          float64
# MonthlyMinSeaLevelPressureValue                 float64
# MonthlyMinSeaLevelPressureValueDate             float64
# MonthlyMinSeaLevelPressureValueTime             float64
# MonthlyMinimumTemperature                       float64
# MonthlySeaLevelPressure                         float64
# MonthlyStationPressure                          float64
# MonthlyTotalLiquidPrecipitation                 float64
# MonthlyTotalSnowfall                             object
# MonthlyWetBulb                                  float64
# MonthlyAverageWindSpeed                         float64
# CoolingDegreeDaysSeasonToDate                   float64
# MonthlyCoolingDegreeDays                        float64
# MonthlyNumberDaysWithSnowfall                   float64
# HeatingDegreeDaysSeasonToDate                   float64
# MonthlyHeatingDegreeDays                        float64
# MonthlyNumberDaysWithThunderstorms              float64
# MonthlyNumberDaysWithHeavyFog                   float64
# NormalsCoolingDegreeDay                         float64
# NormalsHeatingDegreeDay                         float64
# ShortDurationEndDate005                          object
# ShortDurationEndDate010                          object
# ShortDurationEndDate015                          object
# ShortDurationEndDate020                          object
# ShortDurationEndDate030                          object
# ShortDurationEndDate045                          object
# ShortDurationEndDate060                          object
# ShortDurationEndDate080                          object
# ShortDurationEndDate100                          object
# ShortDurationEndDate120                          object
# ShortDurationEndDate150                          object
# ShortDurationEndDate180                          object
# ShortDurationPrecipitationValue005              float64
# ShortDurationPrecipitationValue010              float64
# ShortDurationPrecipitationValue015              float64
# ShortDurationPrecipitationValue020              float64
# ShortDurationPrecipitationValue030              float64
# ShortDurationPrecipitationValue045              float64
# ShortDurationPrecipitationValue060              float64
# ShortDurationPrecipitationValue080              float64
# ShortDurationPrecipitationValue100              float64
# ShortDurationPrecipitationValue120              float64
# ShortDurationPrecipitationValue150              float64
# ShortDurationPrecipitationValue180              float64
# REM                                              object
# BackupDirection                                  object
# BackupDistance                                  float64
# BackupDistanceUnit                               object
# BackupElements                                   object
# BackupElevation                                   int64
# BackupEquipment                                  object
# BackupLatitude                                  float64
# BackupLongitude                                 float64
# BackupName                                       object
# WindEquipmentChangeDate                          object
# dtype: object

# %%
#1c
indy_climatedata_2006['DATE'] = pd.to_datetime(indy_climatedata_2006['DATE'])

indy_climatedata_2006['DATE'].head()
# Out:
# 0   2006-01-01 00:00:00
# 1   2006-01-01 00:00:00
# 2   2006-01-01 00:00:00
# 3   2006-01-01 00:02:00
# 4   2006-01-01 00:55:00
# Name: DATE, dtype: datetime64[ns]

# %%
#1d
indy_climatedata_2006['DATE'].dt.date.nunique()
# Out:
# 365

# %% [markdown]
# Markdown notes and sentences and analysis written here.

# %% [markdown]
# ## Question 2

# %%
# %%bash
#
# ls /anvil/projects/tdm/data/noaa_timeseries/
# Out:
# indyclimatedata_2006.csv
# indyclimatedata_2007.csv
# indyclimatedata_2008.csv
# indyclimatedata_2009.csv
# indyclimatedata_2010.csv
# indyclimatedata_2011.csv
# indyclimatedata_2012.csv
# indyclimatedata_2013.csv
# indyclimatedata_2014.csv
# indyclimatedata_2015.csv
# indyclimatedata_2016.csv
# indyclimatedata_2017.csv
# indyclimatedata_2018.csv
# indyclimatedata_2019.csv
# indyclimatedata_2020.csv
# indyclimatedata_2021.csv
# indyclimatedata_2022.csv
# indyclimatedata_2023.csv
# indyclimatedata_2024.csv

# %%
#2a
import pandas as pd

def load_and_stack_climate_data(start_year=2006, end_year=2024, base_path="/anvil/projects/tdm/data/noaa_timeseries/"):
    dfs = []
    for year in range(start_year, end_year + 1):
        file_path = f"{base_path}indyclimatedata_{year}.csv"
        try:
            df = pd.read_csv(file_path, low_memory=False)
            df['year'] = year
            dfs.append(df)
        except FileNotFoundError:
            print(f"File not found for year {year}: {file_path}")
            continue
    combined_df = pd.concat(dfs, ignore_index=True)
    return combined_df

# %%
#2b
combined_df = load_and_stack_climate_data()

# Total number of rows
total_rows = len(combined_df)
print(f"Total rows in combined dataset: {total_rows}")

# Breakdown by year
yearly_counts = combined_df['year'].value_counts().sort_index()
print("\nRows per year:")
print(yearly_counts)
# Out:
# Total rows in combined dataset: 271895
#
# Rows per year:
# year
# 2006    16764
# 2007    14059
# 2008    14260
# 2009    14295
# 2010    14163
# 2011    14310
# 2012    13845
# 2013    14328
# 2014    14378
# 2015    14125
# 2016    14086
# 2017    13968
# 2018    14357
# 2019    14265
# 2020    14231
# 2021    14147
# 2022    14121
# 2023    13911
# 2024    14282
# Name: count, dtype: int64

# %%
#2c
DF = combined_df = load_and_stack_climate_data()
columns_to_keep = ["DATE", "DailyAverageDryBulbTemperature", "DailyMaximumDryBulbTemperature", "DailyMinimumDryBulbTemperature", "DailyPrecipitation", "DailyAverageRelativeHumidity", "DailyAverageWindSpeed","DailySnowfall", "NAME"]

all_years_df_indy_climate = DF[columns_to_keep]

all_years_df_indy_climate.head()
# Out:
#                   DATE  DailyAverageDryBulbTemperature  \
# 0  2006-01-01T00:00:00                             NaN
# 1  2006-01-01T00:00:00                             4.5
# 2  2006-01-01T00:00:00                             NaN
# 3  2006-01-01T00:02:00                             NaN
# 4  2006-01-01T00:55:00                             NaN
#
#    DailyMaximumDryBulbTemperature  DailyMinimumDryBulbTemperature  \
# 0                             NaN                             NaN
# 1                            10.6                            -1.7
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                             NaN                             NaN
#
#   DailyPrecipitation  DailyAverageRelativeHumidity  DailyAverageWindSpeed  \
# 0                NaN                           NaN                    NaN
# 1                0.0                          74.0                    5.1
# 2                NaN                           NaN                    NaN
# 3                NaN                           NaN                    NaN
# 4                NaN                           NaN                    NaN
#
#   DailySnowfall                                       NAME
# 0           NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 1           0.0  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 2           NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 3           NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 4           NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US

# %%
#There are multiple observations per day, but only one has a weather input. The rest are Na. I would just ignore Na entries

# %% [markdown]
# Increasing these values allows for more precise coloring and the image looks more like the clear image. It gets clearer and sharper the more I increase the K value and criteria parameters.

# %% [markdown]
# ## Question 3

# %%
#3a

all_years_df_indy_climate.head(20)
# Out:
#                    DATE  DailyAverageDryBulbTemperature  \
# 0   2006-01-01T00:00:00                             NaN
# 1   2006-01-01T00:00:00                             4.5
# 2   2006-01-01T00:00:00                             NaN
# 3   2006-01-01T00:02:00                             NaN
# 4   2006-01-01T00:55:00                             NaN
# 5   2006-01-01T01:00:00                             NaN
# 6   2006-01-01T01:55:00                             NaN
# 7   2006-01-01T02:00:00                             NaN
# 8   2006-01-01T02:55:00                             NaN
# 9   2006-01-01T03:00:00                             NaN
# 10  2006-01-01T03:55:00                             NaN
# 11  2006-01-01T04:00:00                             NaN
# 12  2006-01-01T04:55:00                             NaN
# 13  2006-01-01T05:00:00                             NaN
# 14  2006-01-01T05:55:00                             NaN
# 15  2006-01-01T06:00:00                             NaN
# 16  2006-01-01T06:55:00                             NaN
# 17  2006-01-01T07:00:00                             NaN
# 18  2006-01-01T07:55:00                             NaN
# 19  2006-01-01T08:00:00                             NaN
#
#     DailyMaximumDryBulbTemperature  DailyMinimumDryBulbTemperature  \
# 0                              NaN                             NaN
# 1                             10.6                            -1.7
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
# 5                              NaN                             NaN
# 6                              NaN                             NaN
# 7                              NaN                             NaN
# 8                              NaN                             NaN
# 9                              NaN                             NaN
# 10                             NaN                             NaN
# 11                             NaN                             NaN
# 12                             NaN                             NaN
# 13                             NaN                             NaN
# 14                             NaN                             NaN
# 15                             NaN                             NaN
# 16                             NaN                             NaN
# 17                             NaN                             NaN
# 18                             NaN                             NaN
# 19                             NaN                             NaN
#
#    DailyPrecipitation  DailyAverageRelativeHumidity  DailyAverageWindSpeed  \
# 0                 NaN                           NaN                    NaN
# 1                 0.0                          74.0                    5.1
# 2                 NaN                           NaN                    NaN
# 3                 NaN                           NaN                    NaN
# 4                 NaN                           NaN                    NaN
# 5                 NaN                           NaN                    NaN
# 6                 NaN                           NaN                    NaN
# 7                 NaN                           NaN                    NaN
# 8                 NaN                           NaN                    NaN
# 9                 NaN                           NaN                    NaN
# 10                NaN                           NaN                    NaN
# 11                NaN                           NaN                    NaN
# 12                NaN                           NaN                    NaN
# 13                NaN                           NaN                    NaN
# 14                NaN                           NaN                    NaN
# 15                NaN                           NaN                    NaN
# 16                NaN                           NaN                    NaN
# 17                NaN                           NaN                    NaN
# 18                NaN                           NaN                    NaN
# 19                NaN                           NaN                    NaN
#
#    DailySnowfall                                       NAME
# 0            NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 1            0.0  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 2            NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 3            NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 4            NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 5            NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 6            NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 7            NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 8            NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 9            NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 10           NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 11           NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 12           NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 13           NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 14           NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 15           NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 16           NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 17           NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 18           NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 19           NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US

# %%
# Create a list of weather-related columns to check
cols_to_check = [col for col in all_years_df_indy_climate.columns if col not in ["DATE", "NAME"]]

# Drop rows where all weather columns are missing
all_years_df_indy_climate = all_years_df_indy_climate.dropna(subset=cols_to_check, how='all')

# %%
all_years_df_indy_climate.head(20)
# Out:
#                      DATE  DailyAverageDryBulbTemperature  \
# 1     2006-01-01T00:00:00                             4.5
# 54    2006-01-02T00:00:00                            13.3
# 116   2006-01-03T00:00:00                             7.0
# 177   2006-01-04T00:00:00                             6.4
# 234   2006-01-05T00:00:00                             1.7
# 291   2006-01-06T00:00:00                            -0.8
# 354   2006-01-07T00:00:00                             2.0
# 403   2006-01-08T00:00:00                             7.0
# 452   2006-01-09T00:00:00                             5.8
# 506   2006-01-10T00:00:00                             4.5
# 574   2006-01-11T00:00:00                             5.6
# 638   2006-01-12T00:00:00                             8.1
# 688   2006-01-13T00:00:00                             7.2
# 764   2006-01-14T00:00:00                            -0.2
# 814   2006-01-15T00:00:00                            -0.3
# 863   2006-01-16T00:00:00                             5.8
# 912   2006-01-17T00:00:00                             4.5
# 1008  2006-01-18T00:00:00                            -1.6
# 1069  2006-01-19T00:00:00                             6.1
# 1117  2006-01-20T00:00:00                            12.5
#
#       DailyMaximumDryBulbTemperature  DailyMinimumDryBulbTemperature  \
# 1                               10.6                            -1.7
# 54                              18.3                             8.3
# 116                              8.3                             5.6
# 177                             10.0                             2.8
# 234                              3.3                             0.0
# 291                              0.0                            -1.7
# 354                              6.7                            -2.8
# 403                             15.0                            -1.1
# 452                              9.4                             2.2
# 506                              7.2                             1.7
# 574                              8.9                             2.2
# 638                             13.3                             2.8
# 688                             13.3                             1.1
# 764                              2.8                            -3.3
# 814                              4.4                            -5.0
# 863                             13.3                            -1.7
# 912                             11.7                            -2.8
# 1008                             0.6                            -3.9
# 1069                            13.3                            -1.1
# 1117                            14.4                            10.6
#
#      DailyPrecipitation  DailyAverageRelativeHumidity  DailyAverageWindSpeed  \
# 1                   0.0                          74.0                    5.1
# 54                  6.6                          89.0                    4.9
# 116                 0.5                          96.0                    NaN
# 177                   T                          87.0                    7.7
# 234                   T                          82.0                    5.8
# 291                   T                          72.0                    5.6
# 354                 0.0                          76.0                    5.6
# 403                 0.0                          65.0                    6.6
# 452                 0.0                          77.0                    5.1
# 506                13.2                          87.0                    4.4
# 574                 3.3                          89.0                    6.4
# 638                 0.0                          64.0                    5.9
# 688                19.1                          91.0                    7.3
# 764                   T                          74.0                    7.3
# 814                 0.0                          77.0                    4.2
# 863                 0.0                          70.0                    4.0
# 912                19.8                          95.0                    5.1
# 1008                0.5                          76.0                    6.4
# 1069                0.0                          72.0                    6.7
# 1117                0.5                          75.0                    6.1
#
#      DailySnowfall                                       NAME
# 1              0.0  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 54             0.0  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 116            0.0  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 177            0.0  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 234              T  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 291              T  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 354            0.0  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 403            0.0  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 452            0.0  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 506            0.0  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 574            0.0  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 638            0.0  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 688              T  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 764              T  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 814            0.0  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 863            0.0  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 912           56.0  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 1008          13.0  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 1069           0.0  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 1117           0.0  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US

# %%
# Convert DATE column to datetime format
all_years_df_indy_climate['DATE'] = pd.to_datetime(all_years_df_indy_climate['DATE'], errors='coerce')

# Preview the first few rows to confirm
print(all_years_df_indy_climate[['DATE']].head())
# Out:
#           DATE
# 1   2006-01-01
# 54  2006-01-02
# 116 2006-01-03
# 177 2006-01-04
# 234 2006-01-05

# %%
# Print the shape of the cleaned dataset
print(f"Dataset shape: {all_years_df_indy_climate.shape}")

# Display the range of dates
date_min = all_years_df_indy_climate['DATE'].min().date()
date_max = all_years_df_indy_climate['DATE'].max().date()
print(f"Date range: {date_min} to {date_max}")
# Out:
# Dataset shape: (6940, 9)
# Date range: 2006-01-01 to 2024-12-31

# %% [markdown]
# ## Question 4

# %%
all_years_df_indy_climate['DailyAverageDryBulbTemperature'].interpolate(method="time")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 all_years_df_indy_climate['DailyAverageDryBulbTemperature'].interpolate(method="time")
#
# File /usr/local/lib/python3.12/site-packages/pandas/core/generic.py:8499, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    8497 else:
#    8498     index = missing.get_interp_index(method, obj.index)
# -> 8499     new_data = obj._mgr.interpolate(
#    8500         method=method,
#    8501         index=index,
#    8502         limit=limit,
#    8503         limit_direction=limit_direction,
#    8504         limit_area=limit_area,
#    8505         inplace=inplace,
#    8506         downcast=downcast,
#    8507         **kwargs,
#    8508     )
#    8510 result = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    8511 if should_transpose:
#
# File /usr/local/lib/python3.12/site-packages/pandas/core/internals/base.py:291, in DataManager.interpolate(self, inplace, **kwargs)
#     290 def interpolate(self, inplace: bool, **kwargs) -> Self:
# --> 291     return self.apply_with_block(
#     292         "interpolate",
#     293         inplace=inplace,
#     294         **kwargs,
#     295         using_cow=using_copy_on_write(),
#     296         already_warned=_AlreadyWarned(),
#     297     )
#
# File /usr/local/lib/python3.12/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File /usr/local/lib/python3.12/site-packages/pandas/core/internals/blocks.py:1797, in Block.interpolate(self, method, index, inplace, limit, limit_direction, limit_area, downcast, using_cow, already_warned, **kwargs)
#    1794 copy, refs = self._get_refs_and_copy(using_cow, inplace)
#    1796 # Dispatch to the EA method.
# -> 1797 new_values = self.array_values.interpolate(
#    1798     method=method,
#    1799     axis=self.ndim - 1,
#    1800     index=index,
#    1801     limit=limit,
#    1802     limit_direction=limit_direction,
#    1803     limit_area=limit_area,
#    1804     copy=copy,
#    1805     **kwargs,
#    1806 )
#    1807 data = extract_array(new_values, extract_numpy=True)
#    1809 if (
#    1810     not copy
#    1811     and warn_copy_on_write()
#    1812     and already_warned is not None
#    1813     and not already_warned.warned_already
#    1814 ):
#
# File /usr/local/lib/python3.12/site-packages/pandas/core/arrays/numpy_.py:296, in NumpyExtensionArray.interpolate(self, method, axis, index, limit, limit_direction, limit_area, copy, **kwargs)
#     293     out_data = self._ndarray.copy()
#     295 # TODO: assert we have floating dtype?
# --> 296 missing.interpolate_2d_inplace(
#     297     out_data,
#     298     method=method,
#     299     axis=axis,
#     300     index=index,
#     301     limit=limit,
#     302     limit_direction=limit_direction,
#     303     limit_area=limit_area,
#     304     **kwargs,
#     305 )
#     306 if not copy:
#     307     return self
#
# File /usr/local/lib/python3.12/site-packages/pandas/core/missing.py:373, in interpolate_2d_inplace(data, index, axis, method, limit, limit_direction, limit_area, fill_value, mask, **kwargs)
#     371 if method == "time":
#     372     if not needs_i8_conversion(index.dtype):
# --> 373         raise ValueError(
#     374             "time-weighted interpolation only works "
#     375             "on Series or DataFrames with a "
#     376             "DatetimeIndex"
#     377         )
#     378     method = "values"
#     380 limit_direction = validate_limit_direction(limit_direction)
#
# ValueError: time-weighted interpolation only works on Series or DataFrames with a DatetimeIndex

# %%
#DF = all_years_df_indy_climate
all_years_df_indy_climate["DATE"] = pd.to_datetime(all_years_df_indy_climate["DATE"]) # Ensure DATE is datetime format
all_years_df_indy_climate = all_years_df_indy_climate.set_index("DATE") # Set DATE as index
all_years_df_indy_climate["DailyAverageDryBulbTemperature"].interpolate(method='time', limit_direction='both')
# Preview a few rows to confirm interpolation
print(all_years_df_indy_climate["DailyAverageDryBulbTemperature"].head(10))
# Out:
# DATE
# 2006-01-01 00:00:00    NaN
# 2006-01-01 00:00:00    4.5
# 2006-01-01 00:00:00    NaN
# 2006-01-01 00:02:00    NaN
# 2006-01-01 00:55:00    NaN
# 2006-01-01 01:00:00    NaN
# 2006-01-01 01:55:00    NaN
# 2006-01-01 02:00:00    NaN
# 2006-01-01 02:55:00    NaN
# 2006-01-01 03:00:00    NaN
# Name: DailyAverageDryBulbTemperature, dtype: float64

# %%
#all_years_df_indy_climate["DailyPrecipitation"].astype(float)

# %%
all_years_df_indy_climate.reset_index(inplace=True)

# %%
all_years_df_indy_climate["DailyPrecipitation"] = all_years_df_indy_climate["DailyPrecipitation"].replace("T", 0)
all_years_df_indy_climate["DailyPrecipitation"] = all_years_df_indy_climate["DailyPrecipitation"].astype(float)

# %%
all_years_df_indy_climate.head()
# Out:
#                  DATE  index  DailyAverageDryBulbTemperature  \
# 0 2006-01-01 00:00:00      0                             NaN
# 1 2006-01-01 00:00:00      1                             4.5
# 2 2006-01-01 00:00:00      2                             NaN
# 3 2006-01-01 00:02:00      3                             NaN
# 4 2006-01-01 00:55:00      4                             NaN
#
#    DailyMaximumDryBulbTemperature  DailyMinimumDryBulbTemperature  \
# 0                             NaN                             NaN
# 1                            10.6                            -1.7
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                             NaN                             NaN
#
#    DailyPrecipitation  DailyAverageRelativeHumidity  DailyAverageWindSpeed  \
# 0                 NaN                           NaN                    NaN
# 1                 0.0                          74.0                    5.1
# 2                 NaN                           NaN                    NaN
# 3                 NaN                           NaN                    NaN
# 4                 NaN                           NaN                    NaN
#
#    DailySnowfall                                       NAME  \
# 0            NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 1            0.0  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 2            NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 3            NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
# 4            NaN  INDIANAPOLIS INTERNATIONAL AIRPORT, IN US
#
#    DailyAverageDryBulbTemperature_Farenheit
# 0                                       NaN
# 1                                      40.1
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN

# %%
# Columns likely to contain "T" (trace amounts)
trace_cols = ["DailyPrecipitation", "DailySnowfall", "DailyAverageWindSpeed", "DailyAverageRelativeHumidity"]  # Adjust based on actual column names

for col in trace_cols:
    if col in all_years_df_indy_climate.columns:
        # Replace "T" with 0 and convert to float
       all_years_df_indy_climate[col] = (
            all_years_df_indy_climate[col]
            .replace("T", 0)
            .astype(float)
        )

# Confirm no non-numeric values remain
print(all_years_df_indy_climate[trace_cols].dtypes)
# Out:
# DailyPrecipitation              float64
# DailySnowfall                   float64
# DailyAverageWindSpeed           float64
# DailyAverageRelativeHumidity    float64
# dtype: object

# %% [markdown]
# A variance ratio method looks for points where the variance reduction slows down. This could be a different way to find optimal K.

# %% [markdown]
# ## Question 5

# %%
#5a
DF['DailyAverageDryBulbTemperature_Farenheit'] = (DF['DailyAverageDryBulbTemperature'] * 9/5 +32)

DF['DailyAverageDryBulbTemperature_Farenheit'].head()
# Out:
# 0     NaN
# 1    40.1
# 2     NaN
# 3     NaN
# 4     NaN
# Name: DailyAverageDryBulbTemperature_Farenheit, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.plot(DF['DATE'], DF['DailyAverageDryBulbTemperature_Farenheit'], linewidth=1) # For YOU to Fill in

plt.title('Average Daily Temperature Over Time between 2006–2024 (°F)')
plt.xlabel('Date')
plt.ylabel('Average Temperature (°F)')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# When you increase the compactness_scaler the image gets split into geometric regions, color info is irrelevant or ignored, there are boundaries.
# I think this happens because with high compactness_scaler, spatial coordinates get scaled to 255 × scaler. The coordinate differences dominate in this analysis.
#
# - Two pixels with identical colors but different locations will be far apart in this scaled space

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.

# %%
Colleen
